# %%
import numpy as np
import pandas as pd
import scanpy as sc 
import anndata as ad
#import besca as bc
import h5py 
import glob
import matplotlib.pyplot as plt
import os

# %%
sc.settings.verbosity = 3             
sc.logging.print_header()
sc.settings.set_figure_params(dpi=80, facecolor='white')
sc.set_figure_params(scanpy=True, figsize=(4,4))

# %%
base_path = '/home/EOCRC_atlas/'

# %% [markdown]
# # Annotate Stromal Cells

# %%
# Load raw data for all cells
adata_raw = sc.read_h5ad(os.path.join(base_path, 'data/all_samples_raw_withAnnotation.h5ad'))

# %%
# Cell type variable 
cell_type = 'Stromal'

# %%
# Subcluster and annotate the stromal cells
adata = adata_raw.copy()
del adata_raw 

adata = adata[adata.obs['Annotation_Tier1']==cell_type]
print(adata.shape)

# %%
count_sum = adata.X.sum(axis=1)
# Normalize the data and store normalized data as its own layer for each normalization step 
adata.layers['counts'] = adata.X.copy()
sc.pp.normalize_total(adata, inplace = True, target_sum=1e4)
adata.layers['norm_counts'] = adata.X.copy()
sc.pp.log1p(adata)
adata.layers['log_counts'] = adata.X.copy()

# %%
# check that counts layer is actually integers 
print(adata.layers['counts'][0:20,0:20])
print(adata.layers['norm_counts'][0:20,0:20])
print(adata.layers['log_counts'][0:20,0:20])

# check that you get integers when you un-normalize the data - randomly checking index 3 
unlog1p = unlog1p = np.expm1(adata.X[3, :])
print(unlog1p)
count_check = unlog1p/10000*count_sum[3].item()
print(count_check)

# %%
# Calculate and plot highly variable genes 
sc.pp.highly_variable_genes(adata, min_mean=0.0125, max_mean=3, min_disp=0.5)
sc.pl.highly_variable_genes(adata)

# Store a copy of adata in the .raw field before subsetting to just variable genes (NOT RAW COUNTS)
adata.raw = adata

# Subset to just variable genes 
# Scale the data 
adata = adata[:, adata.var.highly_variable]
sc.pp.scale(adata, max_value=10)  

# Run PCA and generate PCA plots 
sc.tl.pca(adata, svd_solver='arpack')
sc.pl.pca(adata, color='n_genes')
sc.pl.pca_variance_ratio(adata, log=True)

# Calculate nearest neighbors 
sc.pp.neighbors(adata, n_neighbors=10, n_pcs=40)

# Calculate
sc.tl.umap(adata)

# Calculate and plot leiden clusters 
sc.tl.leiden(adata, resolution=.1, key_added = 'leiden_res.1')
sc.pl.umap(adata, color=['leiden_res.1'], size=1)

adata.write_h5ad(os.path.join(base_path, f'data/yocrc_{cell_type}_processed.h5ad'))

# %%
# Optional jump in point 
adata = sc.read_h5ad(os.path.join(base_path, f'data/yocrc_{cell_type}_processed.h5ad'))

# %%
# Plot FRID
import random
colors = ["#%06x" % random.randint(0, 0xFFFFFF) for _ in range(192)]

fig, ax = plt.subplots()
sc.pl.umap(adata, color='FRID', size=1, ax=ax, show=True, palette=colors)
#fig.savefig('/home/cporter/atlas_remake_Aug_26_2024/results/figures/FRID_UMAP.pdf', dpi=600, bbox_inches='tight')
#plt.close(fig)

# %%
# Integrate with harmony (patient batch) 
import scanpy.external as sce
sce.pp.harmony_integrate(adata, key="FRID")
sc.pp.neighbors(adata, n_neighbors=10, n_pcs=40, use_rep='X_pca_harmony')
sc.tl.umap(adata)

import random
colors = ["#%06x" % random.randint(0, 0xFFFFFF) for _ in range(192)]
sc.pl.umap(adata, color='FRID', size=4, palette=colors)

# %%
# Calculate and visualize different clustering resolutions 
sc.tl.leiden(adata, resolution=.05, key_added='harmony_leiden_res.05')
sc.tl.leiden(adata, resolution=.1, key_added='harmony_leiden_res.1')
sc.tl.leiden(adata, resolution=.2, key_added='harmony_leiden_res.2')
sc.tl.leiden(adata, resolution=.3, key_added='harmony_leiden_res.3')
sc.tl.leiden(adata, resolution=.4, key_added='harmony_leiden_res.4')
sc.tl.leiden(adata, resolution=.5, key_added='harmony_leiden_res.5')
sc.tl.leiden(adata, resolution=.6, key_added='harmony_leiden_res.6')
sc.tl.leiden(adata, resolution=.8, key_added='harmony_leiden_res.8')
sc.tl.leiden(adata, resolution=.8, key_added='harmony_leiden_res.9')
sc.tl.leiden(adata, resolution=1, key_added='harmony_leiden_res1')
sc.tl.leiden(adata, resolution=1.5, key_added='harmony_leiden_res1.5')
sc.pl.umap(adata, color=['harmony_leiden_res.05', 'harmony_leiden_res.1', 'harmony_leiden_res.2', 'harmony_leiden_res.3', 
                         'harmony_leiden_res.4', 'harmony_leiden_res.5', 'harmony_leiden_res.6', 'harmony_leiden_res.8', 
                         'harmony_leiden_res.9', 'harmony_leiden_res1', 'harmony_leiden_res1.5'], size=4)

# %%
# plot chosen clustering resolution 
sc.pl.umap(adata, color=['harmony_leiden_res.6'], size=4)

# %%
# Save harmony integrated stromal object 
adata.write_h5ad(os.path.join(base_path, f'data/yocrc_{cell_type}_harmony.h5ad'))

# %%
# Run cell typist
import celltypist
from celltypist import models

#used as reference for comparing manual annotations based on sigantures
predictions = celltypist.annotate(
    adata.raw.to_adata(), 
    model = 'Cells_Intestinal_Tract.pkl', 
    majority_voting = True
)

predict = predictions.to_adata()
tmp = predict.obs['majority_voting'].astype("str")
adata.obs['majority_voting']=tmp
sc.pl.umap(
    adata, color='majority_voting', wspace=0.1, add_outline=False, size=6, 
    legend_fontsize=11, legend_fontoutline=1.5, frameon=False, palette='tab20')

# %%
# Run cell typist
import celltypist
from celltypist import models

#used as reference for comparing manual annotations based on sigantures
predictions = celltypist.annotate(
    adata.raw.to_adata(), 
    model = 'Human_Colorectal_Cancer.pkl', 
    majority_voting = True
)

predict = predictions.to_adata()
tmp = predict.obs['majority_voting'].astype("str")
adata.obs['majority_voting']=tmp
sc.pl.umap(
    adata, color='majority_voting', wspace=0.1, add_outline=False, size=6, 
    legend_fontsize=11, legend_fontoutline=1.5, frameon=False, palette='tab20')

# %%
# Look at typical colon fibroblast markers 
fibro_markers = {
    'CTF' : ['PDGFRA','TNC', 'FOXL1', 'SOX6', 'PROCR', 'BMP2', 'BMP3', 'BMP4', 'BMP5', 'BMP7', 'WNT5A', 'NRG1'],
    'cCF1' : ['CD34', 'THY1', 'COL15A1', 'WNT2', 'WNT2B', 'SFRP1', 'FRZB', 'CD274'],
    'cCF2' : ['GREM1', 'RSPO3', 'IGF1', 'VEGFD', 'CD274']}

for name, markers in fibro_markers.items():
    sc.tl.score_genes(adata, markers, score_name = name, use_raw=True)
    sc.pl.umap(adata, color=markers, size=4)

sc.pl.umap(adata, color=list(fibro_markers.keys()), size=4, cmap='inferno')

# %%
# Look at CRC CAF markers 
fibro_markers = {
    'CAF-A' : ['FAP', 'MMP2', 'COL1A2'],
    'CAF-B' : ['ACTA2', 'TAGLN'],
    'apCAF' : ['HLA-DRA', 'HLA-DPA1', 'HLA-DQA1', 'CD74']}

for name, markers in fibro_markers.items():
    sc.tl.score_genes(adata, markers, score_name = name, use_raw=True)
    sc.pl.umap(adata, color=markers, size=4)

sc.pl.umap(adata, color=list(fibro_markers.keys()), size=4, cmap='inferno')

# %%
# Look at general CAF markers 
fibro_markers = {
    'inflCAF' : ['IL6', 'PDGFRA'],
    'imm-regCAF' : ['CXCL12'],
    'myCAF' : ['ACTA2', 'TAGLN', 'POSTN'],
    'apCAF' : ['HLA-DRA', 'HLA-DPA1', 'HLA-DQA1', 'CD74']}

for name, markers in fibro_markers.items():
    sc.tl.score_genes(adata, markers, score_name = name, use_raw=True)
    sc.pl.umap(adata, color=markers, size=4)

sc.pl.umap(adata, color=list(fibro_markers.keys()), size=4, cmap='inferno')

# %%
# Look at Matan stromal markers
sc.pl.umap(adata, color=['COL1A1', 'INHBA', 'ACTA2', 'CXCL14', 'BMP5', 'BMP4', 'BMP2', 'GREM1', 'RSPO3', 'MMP3'], size=4)

# %%
# Look at all of Pelka et al markers 
df = pd.read_csv(os.path.join(base_path, 'docs/hofree_stromal_markers.csv'), keep_default_na=False)
subsets = df.columns
for s in subsets:
    sc.tl.score_genes(adata, df[s].values[1:df.shape[0]], score_name = s, use_raw=True)

sc.pl.umap(adata, color=subsets, size=2, cmap='inferno')

# %%
# plot markers indiciating contaminating cell types 
sc.pl.umap(adata, color=['EPCAM', 'PTPRC', 'PECAM1'])

# %%
# look for inflammatory fibroblasts looking at more detailed cell subsets from L. Kong's paper 
fibro_markers = {
    'infl_fibro' :  ['CHI3L1', 'IL11', 'MMP3', 'MMP1', 'TNC'],
    'activated_fibro' : ['CCL19', 'ADAMDEC1'],
    'ademdec1' :  ['CCL11', 'ADAMDEC1', 'CCL13', 'HAPLN1'], 
    'kcnn3_ly6h' : ['KCNN3', 'LY6H', 'DPT', 'C7',  'SCN7A'],
    'npy_slitrk6' : ['NPY', 'SLITRK6', 'F3', 'EDNRB', 'NSG1'],
    'sfrp2_slp1' :  ['SLPI', 'SFRP2', 'IGFBP6', 'MFAP5'], 
    'smoc2_ptgis' :  ['SMOC2', 'PTGIS', 'F3', 'PCSK6', 'ADAMTSL3', 'PCSK6'], 
    'myofibro_grem' :  ['GREM1', 'GREM2', 'ACTG2', 'DES', 'TAGLN', 'MYH11'], 
    'myofibro_hhip_npnt' :  ['HHIP', 'NPNT', 'SOSTDC1', 'ACTG2', 'ACTA2', 'MYH11', 'TAGLN']}
    
for name, markers in fibro_markers.items():
    sc.tl.score_genes(adata, markers, score_name = name, use_raw=True)
    sc.pl.umap(adata, color=markers, size=4)

sc.pl.umap(adata, color=list(fibro_markers.keys()), size=4, cmap='inferno')

# %%
# Optional jump in point 
adata = sc.read_h5ad(os.path.join(base_path, f'data/yocrc_{cell_type}_processed.h5ad'))

# %%
# Calculate cluster marker genes 
sc.tl.rank_genes_groups(adata, "harmony_leiden_res.8", method="wilcoxon", use_raw = True)

# save marker genes 
df_all = pd.DataFrame()
clusters = np.unique(adata.obs['harmony_leiden_res.8'])
for i in clusters:
    
    df = sc.get.rank_genes_groups_df(adata, group = i)

    #order by zscore
    df['abs_logFC'] = np.absolute(df['logfoldchanges'])
    df = df[['names', 'scores', 'logfoldchanges', 'abs_logFC', 'pvals', 'pvals_adj']]
    print(i)
    print(df)
    
    i = i.replace(" / ", "_")
    i = i.replace(" ", "_")
    
    #df.to_csv(f"/home/cporter/atlas_remake_Aug_26_2024/results/stromal_res.4_markerGenes_{i}.csv")
    
    tmp=df['names'][0:100]
    df_all = pd.concat([df_all, tmp], axis=1)
df_all.columns=clusters
df_all.to_csv(os.path.join(base_path, f'results/{cell_type}_res.8_markerGenes_top100.csv'))

# %%
# Look at top marker genes of each cluster 
for i in range(len(df_all.columns)):
    print(i)
    sc.pl.umap(adata, color=df_all[str(i)][0:20], ncols=10)

# %%
# Cycling score 
cell_cycle_genes = [x.strip() for x in open(os.path.join(base_path, 'docs/regev_lab_cell_cycle_genes.txt'))]
s_genes = cell_cycle_genes[:43]
g2m_genes = cell_cycle_genes[43:]
sc.tl.score_genes_cell_cycle(adata, s_genes=s_genes, g2m_genes=g2m_genes)
sc.pl.umap(adata, color=['phase'])
sc.pl.violin(adata, 'phase', groupby='harmony_leiden_res.5')

# %%
# Load original adata 
adata = sc.read_h5ad(os.path.join(base_path, f'data/yocrc_{cell_type}_harmony.h5ad'))

# %%
# Assign Tier 2 cluster annotations 
tier2annotation = {
    '0' : 'Fibroblast', #
    '1' : 'Fibroblast', #
    '2' : 'Fibroblast', #
    '3' : 'Myofibroblast-SMC', #
    '4' : 'Fibroblast-Infl', #
    '5' : 'Fibroblast-BMP5-SOX6', #
    '6' : 'Fibroblast-KCNN3', #
    '7' : 'Pericytes', #
    '8' : 'Fibroblast-MMP2-THY1', #
    '9' : 'Mixed Stromal', #
    '10' : 'MT-Ribo-hi Stromal', #
    '11' : 'Pericytes', 
    '12' : 'MT-Ribo-hi Stromal', # 
    '13' : 'Mixed Stromal', # 
    '14' : 'Adipocytes', #
    '15' : 'Mixed Stromal', 
    '16' : 'Fibroblast-C3', 
    '17' : 'Mixed Stromal', 
    '18' : 'Cycling Stromal',
    '19' : 'HSP-hi Stromal', 
    '20' : 'Fibroblast-KCNN3', 
    '21' : 'Myofibroblast-SMC'
}
adata.obs['Annotation_Tier2'] = adata.obs['harmony_leiden_res.8'].map(tier2annotation).astype('category')

# %%
sc.pl.umap(adata, color=['Annotation_Tier2'], size=4)

# %%
# save annotated object
adata.write_h5ad(os.path.join(base_path, f'data/yocrc_{cell_type}_annotation.h5ad'))

# %%
# read object in 
adata = sc.read_h5ad(os.path.join(base_path, f'data/yocrc_{cell_type}_annotation.h5ad'))

# %%
# Plot Tier2
colors = ['#000000', '#E69F00', '#0072B2', '#D55E00', '#009E73', '#56B4E9', '#CC79A7','#F0E442','#604882', '#ACAF7A', '#8C564B', '#17BECF', '#7F7F7F']

fig, ax = plt.subplots()
sc.pl.umap(adata, color='Annotation_Tier2', size=3, ax=ax, show=True, palette=colors)
fig.savefig(os.path.join(base_path, f'results/annotations_YOCRC_7-10-25/Annotation_Tier2_UMAP_{cell_type}_Harmony.pdf'), dpi=600, bbox_inches='tight')
plt.close(fig)

# %%
# Plot FRID
import random
colors = ["#%06x" % random.randint(0, 0xFFFFFF) for _ in range(192)]

fig, ax = plt.subplots()
sc.pl.umap(adata, color='FRID', size=3, ax=ax, show=True, palette=colors)
fig.savefig(os.path.join(base_path, f'results/annotations_YOCRC_7-10-25/FRID_UMAP_{cell_type}_Harmony.pdf'), dpi=600, bbox_inches='tight')
plt.close(fig)

# %%
adata_orig = sc.read_h5ad(os.path.join(base_path, f'data/yocrc_{cell_type}_processed.h5ad'))

# %%
# check that sizes check out 
print(sum(adata_orig.obs_names==adata.obs_names))
print(adata.shape)
print(adata_orig.shape)

# %%
# transfer obsm and obs to the raw data object
adata_orig.obs = adata.obs

# %%
adata_orig.write_h5ad(os.path.join(base_path, f'data/yocrc_{cell_type}_annotation_noHarmony.h5ad'))

# %%
# Plot Tier2
colors = ['#000000', '#E69F00', '#0072B2', '#D55E00', '#009E73', '#56B4E9', '#CC79A7','#F0E442','#604882', '#ACAF7A', '#8C564B', '#17BECF', '#7F7F7F']

fig, ax = plt.subplots()
sc.pl.umap(adata_orig, color='Annotation_Tier2', size=7, ax=ax, show=True, palette=colors)
fig.savefig(os.path.join(base_path, f'results/annotations_YOCRC_7-10-25/Annotation_Tier2_UMAP_{cell_type}_NoHarmony.pdf'), dpi=600, bbox_inches='tight')
plt.close(fig)

# %%
# Plot and save metadata on UMAP
colors = ['#000000', '#E69F00', '#56B4E9', '#009E73', '#F0E442', '#0072B2', '#D55E00', '#CC79A7']
sc.set_figure_params(figsize=(4, 4))

# Plot DECADE
fig, ax = plt.subplots()
sc.pl.umap(adata_orig, color='Decade', size=3, ax=ax, show=True, palette=colors)
fig.savefig(os.path.join(base_path, f'results/annotations_YOCRC_7-10-25/Decade_UMAP_{cell_type}_NoHarmony.pdf'), dpi=600, bbox_inches='tight')
plt.close(fig)

# Plot AGE COHORT
fig, ax = plt.subplots()
sc.pl.umap(adata_orig, color='Cohort', size=3, ax=ax, show=True, palette=colors[5:7])
fig.savefig(os.path.join(base_path, f'results/annotations_YOCRC_7-10-25/Cohort_UMAP_{cell_type}_NoHarmony.pdf'), dpi=600, bbox_inches='tight')
plt.close(fig)

# Plot FRID
import random
colors = ["#%06x" % random.randint(0, 0xFFFFFF) for _ in range(192)]

fig, ax = plt.subplots()
sc.pl.umap(adata_orig, color='FRID', size=3, ax=ax, show=True, palette=colors)
fig.savefig(os.path.join(base_path, f'results/annotations_YOCRC_7-10-25/FRID_UMAP_{cell_type}_NoHarmony.pdf'), dpi=600, bbox_inches='tight')
plt.close(fig)
